# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time
import warnings
warnings.filterwarnings("ignore")

import seaborn as sns
import matplotlib.pyplot as plt

from graph_api import *

# %% [markdown]
# # API

# %%
fb_api = open("tokens/fb_token").read()
ad_acc = "3120164588217844"

graph = GraphAPI(ad_acc, fb_api)

# %% [markdown]
# # Carregando o dataset

# %%
df = pd.read_csv('ads_full.csv', sep=';')

# %%
df_ads = pd.DataFrame()

# %%
d = (datetime.today() - pd.to_datetime(df['date_start'].max())).days
if d >= 2:
    for i in range(d-1):
        while True:
            try:
                #df_temp = graph.get_ads_status(since_until=[(datetime.today() - timedelta(days=i+1)).strftime("%Y-%m-%d"),(datetime.today() - timedelta(days=i+1)).strftime("%Y-%m-%d")], increment=1, process=1, filter='GREATER_THAN', impressions=50000, effective_status=['CAMPAIGN_PAUSED'])
                #df_temp2 = graph.get_ads_status(since_until=[(datetime.today()  - timedelta(days=i+1)).strftime("%Y-%m-%d"),(datetime.today() - timedelta(days=i+1)).strftime("%Y-%m-%d")], increment=1, process=1, filter='LESS_THAN_OR_EQUAL', impressions=50000, effective_status=['CAMPAIGN_PAUSED'])
                df_temp3 = graph.get_ads_status(since_until=[(datetime.today() - timedelta(days=i+1)).strftime("%Y-%m-%d"),(datetime.today() - timedelta(days=i+1)).strftime("%Y-%m-%d")], increment=1, process=1, filter='GREATER_THAN', impressions=0, effective_status=['PAUSED','ACTIVE','ADSET_PAUSED'])
                #df_ads = df_ads.append(df_temp)
                #df_ads = df_ads.append(df_temp2)
                df_ads = df_ads.append(df_temp3)
                print(i)
                break
            except:
                time.sleep(30)
                print('erro',i)
# Out:
# erro 0
# 0

# %%
df_ads = df_ads[df_ads['insights'].notna()].reset_index(drop=True)

# %%
df_ads_data_insights = pd.DataFrame()

# %%
df4 = pd.DataFrame({'name':None}, index=[0])

#df2 = pd.DataFrame({'name':[None],'product':[None],'type':[None],'date_start':[None],'date_stop':[None],'spend':[None]})
for i in range(len(df_ads)):
    for j in range(len(df_ads['insights'][i]['data'])):
        df4['name'] = df_ads['name'][i]
        df4['status'] = df_ads['status'][i]
        df4['product'] = df_ads['product'][i]
        df4['kind'] = df_ads['kind'][i]
        df4['objective'] = df_ads['objective'][i]
        df4['adset_name'] = df_ads['adset_name'][i]
        df4['insta_link'] = df_ads['insta_link'][i]
        df4['thumb_link'] = df_ads['thumb_link'][i]
        df4['date_start'] = df_ads['insights'][i]['data'][j]['date_start']
        df4['date_stop'] = df_ads['insights'][i]['data'][j]['date_stop']
        df4['spend'] = float(df_ads['insights'][i]['data'][j]['spend'])
        df4['clicks'] = int(df_ads['insights'][i]['data'][j]['clicks'])
        df4['impressions'] = int(df_ads['insights'][i]['data'][j]['impressions'])
        df4['frequency'] = float(df_ads['insights'][i]['data'][j]['frequency'])
        df4['reach'] = int(df_ads['insights'][i]['data'][j]['reach'])
        df4['ctr'] = df_ads['insights'][i]['data'][j].get('ctr') if df_ads['insights'][i]['data'][j].get('ctr') is None else float(df_ads['insights'][i]['data'][j].get('ctr'))
        df4['cpc'] = df_ads['insights'][i]['data'][j].get('cpc') if df_ads['insights'][i]['data'][j].get('cpc') is None else float(df_ads['insights'][i]['data'][j].get('cpc'))
        df4['cpm'] = df_ads['insights'][i]['data'][j].get('cpm') if df_ads['insights'][i]['data'][j].get('cpm') is None else float(df_ads['insights'][i]['data'][j].get('cpm'))
        df4['video_25'] = df_ads['insights'][i]['data'][j].get('video_p25_watched_actions') if df_ads['insights'][i]['data'][j].get('video_p25_watched_actions') is None else int(df_ads['insights'][i]['data'][j]['video_p25_watched_actions'][0]['value'])
        df4['video_50'] = df_ads['insights'][i]['data'][j].get('video_p50_watched_actions') if df_ads['insights'][i]['data'][j].get('video_p50_watched_actions') is None else int(df_ads['insights'][i]['data'][j]['video_p50_watched_actions'][0]['value'])
        df4['video_75'] = df_ads['insights'][i]['data'][j].get('video_p75_watched_actions') if df_ads['insights'][i]['data'][j].get('video_p75_watched_actions') is None else int(df_ads['insights'][i]['data'][j]['video_p75_watched_actions'][0]['value'])
        
        try:
            x = df_ads['insights'][i]['data'][j]['actions'].index({'action_type': 'purchase', 'value': '1'})
            df4['purchase'] = int(df_ads['insights'][i]['data'][j]['actions'][x]['value'])
            df4['purchase_roas'] = float(df_ads['insights'][i]['data'][j]['purchase_roas'][0]['value'])
        except:
            df4['purchase'] = 0
            df4['purchase_roas'] = 0
            
        for k in range(len(df_ads['targetingsentencelines'][i]['targetingsentencelines'])):
            try:
                col = df_ads['targetingsentencelines'][i]['targetingsentencelines'][k]['content']
                row = df_ads['targetingsentencelines'][i]['targetingsentencelines'][k]['children']
                df4[col] = row
            except:
                df4[col] = 0
                
        
        df_ads_data_insights = df_ads_data_insights.append(df4)
        
df_ads_data_insights.reset_index(drop=True, inplace=True)

for i in range(len(df_ads_data_insights['Posicionamentos:'])):
    df_ads_data_insights['Posicionamentos:'][i] = df_ads_data_insights['Posicionamentos:'][i].split(',')

# %%
df_ads_data_insights['date_start'] = pd.to_datetime(df_ads_data_insights['date_start'])
df_ads_data_insights = df_ads_data_insights.sort_values(by='date_start')
df_ads_data_insights['year'] = df_ads_data_insights['date_start'].dt.month
df_ads_data_insights['month'] = df_ads_data_insights['date_start'].dt.month
df_ads_data_insights['day'] = df_ads_data_insights['date_start'].dt.day

# %%
#valor de compra
df_ads_data_insights['purchase_value'] = df_ads_data_insights['purchase_roas'] * df_ads_data_insights['spend']
errors = df_ads_data_insights.query("purchase_value >= 9999").index
df_ads_data_insights.drop(errors, inplace=True)
df_ads_data_insights.reset_index(inplace=True, drop=True)

# %%
df_temperatura = pd.read_csv('adsets_temp.csv', sep=',')
df_ads_data_insights = pd.merge(df_ads_data_insights, df_temperatura, how='left',left_on=['adset_name'],right_on=['ADSET'])

# %%
df_ads_data_insights[df_ads_data_insights['TEMPERATURA'].isna()]['name'].unique()
# Out:
# array([], dtype=object)

# %%
df = df.append(df_ads_data_insights)
df.reset_index(drop=True, inplace=True)
df['date_start'] = pd.to_datetime(df['date_start'])
df['date_stop'] = pd.to_datetime(df['date_stop'])

# %%
#dados acumulados por campanha
df['purchase_acc'] = df.groupby(['name','adset_name'])['purchase'].cumsum()
df['spend_acc'] = df.groupby(['name','adset_name'])['spend'].cumsum()
df['cpa'] = df['spend'] / df['purchase']
df['cpa_acc'] = df['spend_acc'] / df['purchase_acc']

df['purchase_value_acc'] = df.groupby(['name','adset_name'])['purchase_value'].cumsum()
df['purchase_roas_acc'] = df['purchase_value_acc'] / df['spend_acc']

df['clicks_acc'] = df.groupby(['name','adset_name'])['clicks'].cumsum()
df['impressions_acc'] = df.groupby(['name','adset_name'])['impressions'].cumsum()
df['reach_acc'] = df.groupby(['name','adset_name'])['reach'].cumsum()
df['frequency_acc'] = df['impressions_acc'] / df['reach_acc']
df['cpc_acc'] = df['spend_acc'] / df['clicks_acc']
df['cpm_acc'] = (df['spend_acc'] / df['impressions_acc']) * 1000
df['ctr_acc'] = df['clicks_acc'] / df['impressions_acc'] * 100

df.replace([np.inf, -np.inf], 0, inplace=True)

df['video_25_acc'] = df.groupby(['name','adset_name'])['video_25'].cumsum()
df['video_50_acc'] = df.groupby(['name','adset_name'])['video_50'].cumsum()
df['video_75_acc'] = df.groupby(['name','adset_name'])['video_75'].cumsum()

# %%
df.to_csv('ads_full.csv', sep=';', index=False, decimal='.')

# %%
#quartis
quart_size = floor(len(agg) / 4)
q1 = agg[:quart_size]
q2 = agg[quart_size:quart_size*2]
q3 = agg[quart_size*2:quart_size*3]
q4 = agg[quart_size*3:]

# %%
quart = [q1, q2, q3, q4]
for i in range(4): 
    print(f'{i+1}º QUARTIL')
    display(quart[i])
# Out:
# 1º QUARTIL
#                                                     dias  clicks  impressions  \
# name
# [DIP] 12_video_vendas_dash                            22      19          831
# 55_salesanalysis_REELS                                 8     367        21884
# [DIP] 3_cursos_trilha (vídeo)                         22     116         6994
# 27_GasPrice_Nativo2                                    8     144         8837
# 06_nativo_leitorboleto_STORY                          22   12404       762913
# [AT] 03_at_geral                                      22     464        29095
# [DIP] Dashboard_nyc2 (vídeo)                          22      10          648
# [DIP] 5_Projetos (vídeo)                              22      28         1826
# 09_automacao_excel_FEED                               22    1505       101135
# [DIP] Imagem_3_remarketing                            22     205        14785
# [DIP] Porque_aprender_python (estático)               22      67         5158
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...    22      68         5707
#
#                                                       spend  purchase   ctr  \
# name
# [DIP] 12_video_vendas_dash                            46.61         0  2.29
# 55_salesanalysis_REELS                               296.60         0  1.68
# [DIP] 3_cursos_trilha (vídeo)                        198.79         0  1.66
# 27_GasPrice_Nativo2                                  132.05         0  1.63
# 06_nativo_leitorboleto_STORY                        4679.61         4  1.63
# [AT] 03_at_geral                                     940.96         4  1.59
# [DIP] Dashboard_nyc2 (vídeo)                          18.66         0  1.54
# [DIP] 5_Projetos (vídeo)                              97.07         0  1.53
# 09_automacao_excel_FEED                              968.28         0  1.49
# [DIP] Imagem_3_remarketing                           334.99         1  1.39
# [DIP] Porque_aprender_python (estático)              151.59         0  1.30
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...   228.83         1  1.19
#
#                                                       cpm  roas   cpc  \
# name
# [DIP] 12_video_vendas_dash                          56.09  0.00  2.45
# 55_salesanalysis_REELS                              13.55  0.00  0.81
# [DIP] 3_cursos_trilha (vídeo)                       28.42  0.00  1.71
# 27_GasPrice_Nativo2                                 14.94  0.00  0.92
# 06_nativo_leitorboleto_STORY                         6.13  0.85  0.38
# [AT] 03_at_geral                                    32.34  3.72  2.03
# [DIP] Dashboard_nyc2 (vídeo)                        28.80  0.00  1.87
# [DIP] 5_Projetos (vídeo)                            53.16  0.00  3.47
# 09_automacao_excel_FEED                              9.57  0.00  0.64
# [DIP] Imagem_3_remarketing                          22.66  2.99  1.63
# [DIP] Porque_aprender_python (estático)             29.39  0.00  2.26
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...  40.10  4.37  3.37
#
#                                                         cpa     score  \
# name
# [DIP] 12_video_vendas_dash                             0.00     43.44
# 55_salesanalysis_REELS                                 0.00    615.47
# [DIP] 3_cursos_trilha (vídeo)                          0.00    192.39
# 27_GasPrice_Nativo2                                    0.00    234.65
# 06_nativo_leitorboleto_STORY                        1169.90  20167.33
# [AT] 03_at_geral                                     235.24    739.98
# [DIP] Dashboard_nyc2 (vídeo)                           0.00     15.43
# [DIP] 5_Projetos (vídeo)                               0.00     42.94
# 09_automacao_excel_FEED                                0.00   2239.61
# [DIP] Imagem_3_remarketing                           334.99    284.24
# [DIP] Porque_aprender_python (estático)                0.00     87.03
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...   228.83     81.02
#
#                                                     ctr_delta
# name
# [DIP] 12_video_vendas_dash                             -33.79
# 55_salesanalysis_REELS                                   7.12
# [DIP] 3_cursos_trilha (vídeo)                          -26.53
# 27_GasPrice_Nativo2                                     55.60
# 06_nativo_leitorboleto_STORY                            -1.55
# [AT] 03_at_geral                                        -0.30
# [DIP] Dashboard_nyc2 (vídeo)                           819.75
# [DIP] 5_Projetos (vídeo)                                 2.08
# 09_automacao_excel_FEED                                 14.02
# [DIP] Imagem_3_remarketing                              11.08
# [DIP] Porque_aprender_python (estático)                 23.36
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...      -9.44
# 2º QUARTIL
#                                                     dias  clicks  impressions  \
# name
# [AT] 04_depoimentos_FEED                              22      23         2035
# 07_ml_apartamentos                                    22    2097       189625
# 29_Trailer_legendado                                   8      80         7343
# 08_asimov_news_FEED                                   22    6548       608644
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...    22      29         2696
# [DIP] carrossel rmkt padrão                           22      60         6453
# 10_conversao_ml                                       22    3917       438337
# 48_exceldashboard                                     22    2674       300185
# 47_asimov_associates_REELS                             9     257        30326
# [ML] - 16_acessovitalicio_ds (nativo)                 22      49         5797
# 29_vv100_Python                                       11     140        18536
# 30_frontend_backend                                   22    3774       513540
#
#                                                       spend  purchase   ctr  \
# name
# [AT] 04_depoimentos_FEED                              57.02         0  1.13
# 07_ml_apartamentos                                  3375.73         4  1.11
# 29_Trailer_legendado                                 148.55         0  1.09
# 08_asimov_news_FEED                                 6774.55         4  1.08
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...   147.40         0  1.08
# [DIP] carrossel rmkt padrão                          215.94         0  0.93
# 10_conversao_ml                                     5072.57         4  0.89
# 48_exceldashboard                                   3081.40         1  0.89
# 47_asimov_associates_REELS                           590.06         0  0.85
# [ML] - 16_acessovitalicio_ds (nativo)                212.74         0  0.85
# 29_vv100_Python                                      278.31         0  0.76
# 30_frontend_backend                                 6306.54         2  0.73
#
#                                                       cpm  roas   cpc  \
# name
# [AT] 04_depoimentos_FEED                            28.02  0.00  2.48
# 07_ml_apartamentos                                  17.80  1.07  1.61
# 29_Trailer_legendado                                20.23  0.00  1.86
# 08_asimov_news_FEED                                 11.13  0.59  1.03
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...  54.67  0.00  5.08
# [DIP] carrossel rmkt padrão                         33.46  0.00  3.60
# 10_conversao_ml                                     11.57  0.76  1.30
# 48_exceldashboard                                   10.27  0.32  1.15
# 47_asimov_associates_REELS                          19.46  0.00  2.30
# [ML] - 16_acessovitalicio_ds (nativo)               36.70  0.00  4.34
# 29_vv100_Python                                     15.01  0.00  1.99
# 30_frontend_backend                                 12.28  0.24  1.67
#
#                                                         cpa    score  \
# name
# [AT] 04_depoimentos_FEED                               0.00    26.00
# 07_ml_apartamentos                                   843.93  2319.00
# 29_Trailer_legendado                                   0.00    87.16
# 08_asimov_news_FEED                                 1693.64  7044.56
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...     0.00    31.19
# [DIP] carrossel rmkt padrão                            0.00    55.79
# 10_conversao_ml                                     1268.14  3500.25
# 48_exceldashboard                                   3081.40  2381.96
# 47_asimov_associates_REELS                             0.00   217.80
# [ML] - 16_acessovitalicio_ds (nativo)                  0.00    41.42
# 29_vv100_Python                                        0.00   105.74
# 30_frontend_backend                                 3153.27  2773.51
#
#                                                     ctr_delta
# name
# [AT] 04_depoimentos_FEED                               -26.18
# 07_ml_apartamentos                                      -5.87
# 29_Trailer_legendado                                     9.74
# 08_asimov_news_FEED                                    -11.39
# [DIP] 04_Rm_BenefíciosTrilha (carrossel estátic...      55.15
# [DIP] carrossel rmkt padrão                             30.13
# 10_conversao_ml                                        -13.83
# 48_exceldashboard                                       27.20
# 47_asimov_associates_REELS                              -2.60
# [ML] - 16_acessovitalicio_ds (nativo)                   45.81
# 29_vv100_Python                                         13.86
# 30_frontend_backend                                      6.94
# 3º QUARTIL
#                                         dias  clicks  impressions    spend  \
# name
# 12_video_vendas_dash                      22    1214       178619  2017.88
# 30_frontend_backend_STORY                  8       3          448    16.33
# 26_Projeto_Mercado_Financeiro             22     925       151799  2154.04
# 09_MyBudget                                8     121        19972   262.42
# 07_manipulação_imagens_STORY              22     522        88240   786.81
# 10_Calendar_MyBudget                      22    1270       220706  2797.53
# [ML] - 18_sem_prerequisito_ds (nativo)    22      10         1782    61.46
# 24_4 projetos                              8      45         8549   189.76
# 20_4cursosem1                             22    1589       335493  4012.45
# 57_GameAnalysis_REELS                      8      12         2570    34.91
# 25_carrossel_4cursosDS                     9      36         7786   153.04
# 25_questionario_sistemas                  22    2757       606928  4955.24
#
#                                         purchase   ctr    cpm  roas   cpc  \
# name
# 12_video_vendas_dash                           2  0.68  11.30  0.99  1.66
# 30_frontend_backend_STORY                      0  0.67  36.45  0.00  5.44
# 26_Projeto_Mercado_Financeiro                  0  0.61  14.19  0.00  2.33
# 09_MyBudget                                    0  0.61  13.14  0.00  2.17
# 07_manipulação_imagens_STORY                   0  0.59   8.92  0.00  1.51
# 10_Calendar_MyBudget                           0  0.58  12.68  0.00  2.20
# [ML] - 18_sem_prerequisito_ds (nativo)         0  0.56  34.49  0.00  6.15
# 24_4 projetos                                  0  0.53  22.20  0.00  4.22
# 20_4cursosem1                                  3  0.47  11.96  0.75  2.53
# 57_GameAnalysis_REELS                          0  0.47  13.58  0.00  2.91
# 25_carrossel_4cursosDS                         0  0.46  19.66  0.00  4.25
# 25_questionario_sistemas                       4  0.45   8.16  0.71  1.80
#
#                                             cpa    score  ctr_delta
# name
# 12_video_vendas_dash                    1008.94   825.11      24.36
# 30_frontend_backend_STORY                  0.00     2.01     -12.82
# 26_Projeto_Mercado_Financeiro              0.00   563.66      11.33
# 09_MyBudget                                0.00    73.31       8.59
# 07_manipulação_imagens_STORY               0.00   308.80      91.96
# 10_Calendar_MyBudget                       0.00   730.79      23.87
# [ML] - 18_sem_prerequisito_ds (nativo)     0.00     5.61      -8.63
# 24_4 projetos                              0.00    23.69      88.15
# 20_4cursosem1                           1337.48   752.60      13.74
# 57_GameAnalysis_REELS                      0.00     5.60      49.39
# 25_carrossel_4cursosDS                     0.00    16.65      31.53
# 25_questionario_sistemas                1238.81  1252.38       1.98
# 4º QUARTIL
#                                                dias  clicks  impressions  \
# name
# [DIP] Iniciante_programação (vídeo)              22      14         3255
# [ML] - 19_ser_cientista_dados (nativo)           22       4          958
# 22_trailerds_YT                                   9      89        22116
# [DIP] Suporte_discord (estático novo - story)    21       2          497
# 18_5projetos                                     22    1090       278854
# [ML] - 14_suportediscord (nativo)                22       4         1270
# 03_inscrições_abertas                            10     516       167781
# 23_trilha_perfeita                               22     490       163629
# [ML] - 17_pratica_projetos_ds (nativo)           22      12         4143
# 27_Projeto_Mercado_Imobiliario                   22     263        96718
# 04_benefícios_trilha_ds                           8      62        27963
# 39_carrossel_4projetos                            8       1         1383
#
#                                                  spend  purchase   ctr    cpm  \
# name
# [DIP] Iniciante_programação (vídeo)              77.32         0  0.43  23.75
# [ML] - 19_ser_cientista_dados (nativo)           32.88         0  0.42  34.32
# 22_trailerds_YT                                 259.92         0  0.40  11.75
# [DIP] Suporte_discord (estático novo - story)    14.33         0  0.40  28.83
# 18_5projetos                                   2630.49         1  0.39   9.43
# [ML] - 14_suportediscord (nativo)                39.73         1  0.31  31.28
# 03_inscrições_abertas                          1133.61         0  0.31   6.76
# 23_trilha_perfeita                             1432.42         0  0.30   8.75
# [ML] - 17_pratica_projetos_ds (nativo)           93.08         0  0.29  22.47
# 27_Projeto_Mercado_Imobiliario                  672.18         1  0.27   6.95
# 04_benefícios_trilha_ds                         152.65         0  0.22   5.46
# 39_carrossel_4projetos                            8.42         0  0.07   6.09
#
#                                                 roas   cpc      cpa   score  \
# name
# [DIP] Iniciante_programação (vídeo)             0.00  5.52     0.00    6.02
# [ML] - 19_ser_cientista_dados (nativo)          0.00  8.22     0.00    1.67
# 22_trailerds_YT                                 0.00  2.92     0.00   35.82
# [DIP] Suporte_discord (estático novo - story)   0.00  7.16     0.00    0.80
# 18_5projetos                                    0.38  2.41  2630.49  426.07
# [ML] - 14_suportediscord (nativo)              25.17  9.93    39.73    1.26
# 03_inscrições_abertas                           0.00  2.20     0.00  158.69
# 23_trilha_perfeita                              0.00  2.92     0.00  146.73
# [ML] - 17_pratica_projetos_ds (nativo)          0.00  7.76     0.00    3.48
# 27_Projeto_Mercado_Imobiliario                  1.49  2.56   672.18   71.52
# 04_benefícios_trilha_ds                         0.00  2.46     0.00   13.75
# 39_carrossel_4projetos                          0.00  8.42     0.00    0.07
#
#                                                ctr_delta
# name
# [DIP] Iniciante_programação (vídeo)               -32.83
# [ML] - 19_ser_cientista_dados (nativo)            -12.23
# 22_trailerds_YT                                     1.39
# [DIP] Suporte_discord (estático novo - story)       0.00
# 18_5projetos                                      -21.52
# [ML] - 14_suportediscord (nativo)                 246.46
# 03_inscrições_abertas                              -2.52
# 23_trilha_perfeita                                 -0.71
# [ML] - 17_pratica_projetos_ds (nativo)            -39.23
# 27_Projeto_Mercado_Imobiliario                     -8.10
# 04_benefícios_trilha_ds                             3.32
# 39_carrossel_4projetos                            -72.20

# %%
fig, axes = plt.subplots(1, 3, figsize=(20,10))
#fig.suptitle('CTR')

axes[0].set_title('CTR')
sns.boxplot(ax=axes[0], y=agg['ctr'], orient='v')

axes[1].set_title('CPC')
sns.boxplot(ax=axes[1], y=agg['cpc'], orient='v')

axes[2].set_title('CPM')
sns.boxplot(ax=axes[2], y=agg['cpm'], orient='v')

ax=ax

# %%
plt.figure(figsize=(20,6))
plt.title('CTR X tempo')

a = sns.lineplot(x='date_start', y='ctr_acc', data=df_filter[df_filter['name'] == '18_5projetos'], ci=None)
a = sns.lineplot(x='date_start', y='ctr_acc', data=df_oct[df_oct['name'] == '18_5projetos'], ci=None)
start, end = a.get_xlim()
ax = a.xaxis.set_ticks(np.arange(start, end, 1))
a = plt.xticks(rotation=45)
plt.legend(['18_5projetos'])
ax=ax

# %%
plt.figure(figsize=(20,6))
plt.title('CTR X tempo')

a = sns.lineplot(x='date_start', y='ctr_acc', data=df_filter[df_filter['name'] == '23_trilha_perfeita'], ci=None)
a = sns.lineplot(x='date_start', y='ctr_acc', data=df_oct[df_oct['name'] == '23_trilha_perfeita'], ci=None)
start, end = a.get_xlim()
ax = a.xaxis.set_ticks(np.arange(start, end, 1))
a = plt.xticks(rotation=45)
plt.legend(['23_trilha_perfeita'])
ax=ax

# %%
plt.figure(figsize=(20,6))
plt.title('CTR X tempo')

a = sns.lineplot(x='date_start', y='ctr_acc', data=df_filter[df_filter['name'] == '27_Projeto_Mercado_Imobiliario'], ci=None)
a = sns.lineplot(x='date_start', y='ctr_acc', data=df_oct[df_oct['name'] == '27_Projeto_Mercado_Imobiliario'], ci=None)
start, end = a.get_xlim()
ax = a.xaxis.set_ticks(np.arange(start, end, 1))
a = plt.xticks(rotation=45)
plt.legend(['27_Projeto_Mercado_Imobiliario'])
ax=ax

# %%
plt.figure(figsize=(20,6))
plt.title('CTR X tempo')

a = sns.lineplot(x='date_start', y='ctr_acc', data=df_filter[df_filter['name'] == '[ML] - 17_pratica_projetos_ds (nativo)'], ci=None)
a = sns.lineplot(x='date_start', y='ctr_acc', data=df_oct[df_oct['name'] == '[ML] - 17_pratica_projetos_ds (nativo)'], ci=None)
start, end = a.get_xlim()
ax = a.xaxis.set_ticks(np.arange(start, end, 1))
a = plt.xticks(rotation=45)
plt.legend(['[ML] - 17_pratica_projetos_ds (nativo)'])
ax=ax
